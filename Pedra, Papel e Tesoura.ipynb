# %%
from random import choice

jogador = str(input('Você escolhe: Pedra, Papel ou tesoura? ')).title().strip()

jokenpo = ['Pedra', 'Papel', 'Tesoura']
computador = choice(jokenpo)

print(f'Computaor escolheu: {computador}')
print(f'jogador escolheu: {jogador}')

if jogador == 'Pedra' and computador == 'Tesoura':
    print('Parabéns, você ganhou!')

if jogador == 'Pedra' and computador == 'Papel':
    print('Que Pena! Você Perdeu!')

if jogador == 'Tesoura' and computador == 'Papel':
    print('Parabéns, você ganhou!')

if jogador == 'Tesoura' and computador == 'Pedra':
    print('Que pena! Você Perdeu!')

if jogador == 'Papel' and computador == 'Pedra':
    print('Parabéns, você ganhou!')

if jogador == 'Papel' and computador == 'Tesoura':
    print('Que pena! Você Perdeu!')

elif jogador == computador:
    print('Empate, não houve ganhador!')
# Out:
# Computaor escolheu: Pedra
# jogador escolheu: Pedra
# Empate, não houve ganhador!
